# %%
#widen display #thanks Nick!
from IPython.core.display import display, HTML, clear_output
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # Project Description:
# ## Compare local property values against the availability and quality of surrounding businesses.
#
# ### Team Members:
# Amy, Ebony, Jin, Michael, Syed
#
# ### Datasets:
# Dallas County Appraisals, Google Maps API
#
# ### Questions:
#    1.    Is there a correlation between housing prices and the commercial businesses that are available in that area? (comparing high housing price area vs low housing price)
#    2.    How does the property value compare with the availability of different types of businesses in the area?
#           -  Banks
#           -  Grocery Stores
#           -  Hospitals
#           -  Cafes (Starbucks)
#    3.     Where in the Dallas area are the highest and lowest property values?

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib as plt
import requests
import json
import gmaps
import time

# API Keys
from config import api_key

# %% [markdown]
# ### Gather and clean data from Dallas County Appraisal District (DCAD) which contains the address and value for all properties in Dallas County (~500k records)

# %%
# Read in the Dallas County Appraisal District (DCAD) property values file
file = "Resources/dcad_combined.csv"

#create DataFrame using only the columns we need
dcad_df = pd.read_csv(file, usecols=['PROPERTY_ZIPCODE', 'TOT_VAL'])
dcad_df.head(5)
# Out:
#    PROPERTY_ZIPCODE  TOT_VAL
# 0         750513060   103500
# 1         750513040   145500
# 2         750502208   168040
# 3         750502277   200040
# 4         750617840   151880

# %%
#add column for 5 digit zipcode
dcad_df['ZIPCODE'] = dcad_df['PROPERTY_ZIPCODE'].astype(str).str[:5]
dcad_df.head(5)
# Out:
#    PROPERTY_ZIPCODE  TOT_VAL ZIPCODE
# 0         750513060   103500   75051
# 1         750513040   145500   75051
# 2         750502208   168040   75050
# 3         750502277   200040   75050
# 4         750617840   151880   75061

# %%
#Group Property Values by Zipcode
zip_group = dcad_df.groupby('ZIPCODE')['TOT_VAL']
zip_group.mean().head().map("${:,.2f}".format)
# Out:
# ZIPCODE
# 75001    $315,208.49
# 75006    $202,706.61
# 75007    $200,411.36
# 75019    $415,797.68
# 75038    $358,436.94
# Name: TOT_VAL, dtype: object

# %% [markdown]
# ### Create Dataframe from groupby with proprty count mean value, rename columns, and sort

# %%
zip_group_df = dcad_df.groupby('ZIPCODE')['TOT_VAL'].agg(('count', 'mean'))\
                    .rename(columns={'count':'PropertyValueCount', 'mean':'MeanPropertyValue'})\
                    .sort_values(by='MeanPropertyValue', ascending=False)\
                    .reset_index()

# %% [markdown]
# ### Add columns to DataFrame to store the business data we are going to merge

# %%
zip_group_df["MeanPropertyDollarValue"] = zip_group_df["MeanPropertyValue"].map("${:,.0f}".format)
zip_group_df['Lat'] = "" 
zip_group_df["Lng"] = ""
zip_group_df["City"] = ""
zip_group_df["State"] = ""
zip_group_df = zip_group_df.rename(columns={"ZIPCODE": "Zipcode"})

# %%
zip_group_df.head()
# Out:
#   Zipcode  PropertyValueCount  MeanPropertyValue MeanPropertyDollarValue Lat  \
# 0   75205                6415       1.606362e+06              $1,606,362
# 1   75225                7633       1.207824e+06              $1,207,824
# 2   75201                1326       9.667580e+05                $966,758
# 3   75209                5424       7.230552e+05                $723,055
# 4   75230                9337       7.046378e+05                $704,638
#
#   Lng City State
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Gather data from Google Maps API about businesses by Zipcode
# 1. Geocode each Zipcode from DCAD
# 2. Use lat/lng to search for businesses in each Zipcode
# 3. Merge with property data which will be used to create charts

# %% [markdown]
# ### Geocding: loop through each zipcode and update the lat/lng in our dataframe

# %%
# create a params dict that will be updated with new zipcode each iteration
params = {"key": api_key}

# Loop through the zipcode pd's and run a lat/long search for each
for index, row in zip_group_df.iterrows():
    base_geocode_url = "https://maps.googleapis.com/maps/api/geocode/json"

    zipcode = row['Zipcode']

    # update address key value to zipcode
    params['address'] = zipcode

    # make request
    zips_lat_lng = requests.get(base_geocode_url, params=params)
    
    # convert to json
    zips_lat_lng = zips_lat_lng.json()
    #print(json.dumps(zips_lat_lng, indent=4, sort_keys=True))
    
    #loop through address to find city
    for i in zips_lat_lng['results'][0]['address_components']:
        if i['types'][0] == 'locality':
            zip_group_df.loc[index, "City"] = i['long_name']
    
    #loop though address to find state
    for i in zips_lat_lng['results'][0]['address_components']:
        if i['types'][0] == 'administrative_area_level_1':
            zip_group_df.loc[index, "State"] = i['short_name']
    
    #Update Lat, Long in Dataframe
    zip_group_df.loc[index, "Lat"] = zips_lat_lng["results"][0]["geometry"]["location"]["lat"]
    zip_group_df.loc[index, "Lng"] = zips_lat_lng["results"][0]["geometry"]["location"]["lng"]

# %%
#visualize to lat/lng have been populated
zip_group_df.head()
# Out:
#   Zipcode  PropertyValueCount  MeanPropertyValue MeanPropertyDollarValue  \
# 0   75205                6415       1.606362e+06              $1,606,362
# 1   75225                7633       1.207824e+06              $1,207,824
# 2   75201                1326       9.667580e+05                $966,758
# 3   75209                5424       7.230552e+05                $723,055
# 4   75230                9337       7.046378e+05                $704,638
#
#        Lat      Lng    City State
# 0  32.8326 -96.7976  Dallas    TX
# 1  32.8695 -96.7896  Dallas    TX
# 2  32.7863 -96.7963  Dallas    TX
# 3  32.8539  -96.819  Dallas    TX
# 4  32.9005 -96.7869  Dallas    TX

# %% [markdown]
# ### Function for calling Google Places search and paging through the results

# %%
def findPlaces(params):
    #set global variable so name is returned
    global next_page_token
    global results_list

    #Google Places Search
    base_places_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    response = requests.get(base_places_url, params=params)
    
    search_results = json.loads(response.text)
    results_list = search_results["results"]
    
    #Set next page token. Default is None.
    next_page_token = search_results.get("next_page_token", None)
    
    time.sleep(4) #add delay because it can take a moment before the the page token is actually available to make the subsequent call

    return next_page_token, results_list

# %% [markdown]
# ### Define the types of businesses to lookup:  we chose to focus on essential businesses like banks, supermarkets, hospitals and starbucks

# %%
#Google Places Types: https://developers.google.com/places/web-service/supported_types

#The types list can include multiple categories. A count and mean rating will be added to the final DataFrame for each type
types = ['bank','supermarket','hospital', 'cafe']

bank_names = ['bank', 'credit union']
not_supermarket_names = ['dollar', 'cents', 'liquor', 'convenience']
hospital_names = ['hospital', 'medical center', 'parkland']
cafe_names = ['starbucks']

# %% [markdown]
# ### Count and summarize ratings for each business type using the lat/lng by radius using Google Places API and update our dataframe

# %%
# params dictionary to update each iteration
for each_type in types:
    
    #clear console before starting a new type
    clear_output()
    
    params = {
        #3 mi radius. A Zipcode is not returned in the results, so we cannot 
        #match against our zipcode without doing a reverse lookup for every result
        "radius": 4828,
        "types": each_type,
        "key": api_key,
    }
    
    if each_type == 'cafe':
        params["keyword"] = 'starbucks' 
    else: 
        params["keyword"] = None
    
    #variables for the specific column names for the business type we are searching
    count_column = f"{each_type}_count"
    rating_column = f"{each_type}_rating"
    
    #add columns for the business type we are looking up
    zip_group_df[count_column] = 0
    zip_group_df[rating_column] = 0

   
    # Use the lat/lng we recovered to search for businesses
    for index, row in zip_group_df.iterrows():

        rating_sum = 0
        rating_count = 0
        business_count = 0

        next_page_token = "" #initialize the page token

        # get lat, lng from df
        lat = row["Lat"]
        lng = row["Lng"]

        # change location each iteration while leaving original params in place
        #params["location"] = f"32.8326,-96.7976" #testing 1 lat, lng
        params["location"] = f"{lat},{lng}"

        while next_page_token != None:
            
            params["pagetoken"] = next_page_token
            
            #call places function
            findPlaces(params)

            #Loop through results list to count each business and get rating for each 
            for each_result in results_list:
                
                #get name in lower case
                business_name_lower = each_result["name"].lower()

                #check to make sure a Rating since not all business have a rating
                if each_result.get("rating") != None:
                    
                    #check for names and keywords based on business type to exclude businesses that are not a good match
                    if each_type == "bank" and any(n in business_name_lower for n in bank_names):
                        business_count+=1
                        rating = each_result["rating"]
                        rating_sum += rating                        
                    
                    if each_type == "hospital" and any(n in business_name_lower for n in hospital_names):
                        business_count+=1
                        rating = each_result["rating"]
                        rating_sum += rating     
                    
                    if each_type == "supermarket" and not(any(n in business_name_lower for n in not_supermarket_names)):
                        business_count+=1
                        rating = each_result["rating"]
                        rating_sum += rating
                        
                    if each_type == "cafe" and any(n in business_name_lower for n in cafe_names):
                        business_count+=1
                        rating = each_result["rating"]
                        rating_sum += rating                             
                                
                    #for printing to console
                    info = f'{row["Zipcode"]} | {each_result["name"]} | location: ({round(each_result["geometry"]["location"]["lat"],2)}, {round(each_result["geometry"]["location"]["lng"],2)}) | rating: {each_result.get("rating",0)}'
                    print(info)
            
            #Set Mean Rating to None if no businesses found
            try:
                mean_rating = rating_sum / business_count
                zip_group_df.loc[index, rating_column] = mean_rating
            except(ZeroDivisionError):
                zip_group_df.loc[index, rating_column] = None
                
            #Set business count in dataframe
            zip_group_df.loc[index, count_column] = business_count
            
        print(f'\nTotal number of {each_type}s found for {row["Zipcode"]}: {business_count} | rating_sum: {round(rating_sum,2)} | avg_rating: {round(mean_rating,2)}')
        print(f'------------------------------------------------------------------------------------------------------\n')
# Out:
# 75205 | Hillcrest Bank | location: (32.8, -96.81) | rating: 3.7
# 75205 | Comerica Bank | location: (32.85, -96.77) | rating: 3.2
# 75205 | BBVA Bank | location: (32.86, -96.81) | rating: 4.2
# 75205 | Bank of America Financial Center | location: (32.81, -96.81) | rating: 2.1
# 75205 | Amegy Bank | location: (32.83, -96.78) | rating: 2.3
# 75205 | PlainsCapital Bank | location: (32.8, -96.81) | rating: 4.5
# 75205 | Wells Fargo Bank | location: (32.8, -96.81) | rating: 3.9
# 75205 | Wells Fargo Bank | location: (32.84, -96.75) | rating: 4.4
# 75205 | Wells Fargo Bank | location: (32.85, -96.81) | rating: 4
# 75205 | First Citizens Bank | location: (32.8, -96.8) | rating: 3.4
# 75205 | Chase Bank | location: (32.82, -96.81) | rating: 1.8
# 75205 | Comerica Bank | location: (32.86, -96.8) | rating: 5
# 75205 | Chase Bank | location: (32.81, -96.8) | rating: 3.9
# 75205 | Bank of America Financial Center | location: (32.83, -96.83) | rating: 3
# 75205 | BBVA Bank | location: (32.8, -96.81) | rating: 3.6
# 75205 | Chase Bank | location: (32.81, -96.78) | rating: 2.7
# 75205 | Frost Bank | location: (32.86, -96.8) | rating: 4.5
# 75205 | Regions Bank | location: (32.87, -96.81) | rating: 2.4
# 75205 | Comerica Bank | location: (32.82, -96.75) | rating: 3.3
# 75205 | Inwood National Bank | location: (32.85, -96.82) | rating: 3.9
# 75205 | Round Rock Capital Management | location: (32.8, -96.8) | rating: 5
# 75205 | Cadence Trust | location: (32.86, -96.81) | rating: 5
# 75205 | Texas Capital Bank | location: (32.84, -96.78) | rating: 4.2
# 75205 | Bank of Texas | location: (32.84, -96.79) | rating: 4.3
# 75205 | Bank of Texas | location: (32.85, -96.8) | rating: 4.4
# 75205 | Wells Fargo Bank | location: (32.79, -96.8) | rating: 3
# 75205 | Bank of America Financial Center | location: (32.85, -96.77) | rating: 1.6
# 75205 | Chase Bank | location: (32.86, -96.8) | rating: 3.9
# 75205 | GO Federal Credit Union - Central Branch | location: (32.81, -96.79) | rating: 3.8
# 75205 | Wells Fargo Bank | location: (32.85, -96.77) | rating: 3.2
# 75205 | Capital One Bank | location: (32.79, -96.78) | rating: 3.5
# 75205 | Bank of America Financial Center | location: (32.81, -96.79) | rating: 2.5
# 75205 | Wells Fargo Bank | location: (32.81, -96.75) | rating: 3.7
# 75205 | Comerica Bank | location: (32.82, -96.79) | rating: 3.6
# 75205 | Wells Fargo Bank | location: (32.86, -96.8) | rating: 3
# 75205 | Pegasus Bank | location: (32.84, -96.83) | rating: 5
# 75205 | Comerica Bank | location: (32.84, -96.76) | rating: 5
# 75205 | Chase Bank | location: (32.86, -96.77) | rating: 2.7
# 75205 | ATM (7-Eleven) | location: (32.81, -96.81) | rating: 4
# 75205 | Belmont Wealth Management | location: (32.8, -96.81) | rating: 1
# 75205 | Bank of Texas | location: (32.84, -96.79) | rating: 1
# 75205 | UMB Bank | location: (32.82, -96.79) | rating: 5
# 75205 | Origin Bank | location: (32.81, -96.8) | rating: 5
# 75205 | LegacyTexas | location: (32.85, -96.79) | rating: 3.8
# 75205 | Veritex Community Bank | location: (32.84, -96.77) | rating: 5
# 75205 | First Convenience Bank | location: (32.81, -96.81) | rating: 4.3
# 75205 | BB&T | location: (32.85, -96.82) | rating: 4.3
#
# Total number of banks found for 75205: 41 | rating_sum: 147.5 | avg_rating: 3.6
# ------------------------------------------------------------------------------------------------------
#
# 75225 | BBVA Bank | location: (32.86, -96.81) | rating: 4.2
# 75225 | Comerica Bank | location: (32.85, -96.77) | rating: 3.2
# 75225 | Chase Bank | location: (32.86, -96.84) | rating: 4.3
# 75225 | Bank of America Financial Center | location: (32.88, -96.76) | rating: 2
# 75225 | Wells Fargo Bank | location: (32.85, -96.81) | rating: 4
# 75225 | Comerica Bank | location: (32.86, -96.8) | rating: 5
# 75225 | Comerica Bank | location: (32.86, -96.74) | rating: 2.3
# 75225 | Regions Bank | location: (32.87, -96.81) | rating: 2.4
# 75225 | Frost Bank | location: (32.86, -96.8) | rating: 4.5
# 75225 | Capital One Bank | location: (32.86, -96.76) | rating: 2.4
# 75225 | Cadence Trust | location: (32.86, -96.81) | rating: 5
# 75225 | Inwood National Bank | location: (32.85, -96.82) | rating: 3.9
# 75225 | Texas Capital Bank | location: (32.84, -96.78) | rating: 4.2
# 75225 | Amegy Bank | location: (32.83, -96.78) | rating: 2.3
# 75225 | Bank of Texas | location: (32.84, -96.79) | rating: 4.3
# 75225 | Bank of Texas | location: (32.85, -96.8) | rating: 4.4
# 75225 | Wells Fargo Bank | location: (32.84, -96.75) | rating: 4.4
# 75225 | Chase Bank | location: (32.86, -96.8) | rating: 3.9
# 75225 | Wells Fargo Bank | location: (32.85, -96.77) | rating: 3.2
# 75225 | Bank of America Financial Center | location: (32.85, -96.77) | rating: 1.6
# 75225 | Chase Bank | location: (32.86, -96.77) | rating: 2.7
# 75225 | Comerica Bank | location: (32.87, -96.78) | rating: 1.8
# 75225 | Wells Fargo Bank | location: (32.86, -96.8) | rating: 3
# 75225 | BBVA Bank | location: (32.86, -96.77) | rating: 3.5
# 75225 | Chase Bank | location: (32.89, -96.77) | rating: 2.5
# 75225 | Veritex Community Bank | location: (32.87, -96.8) | rating: 3
# 75225 | Nexbank | location: (32.86, -96.81) | rating: 3
# 75225 | Beal Bank | location: (32.87, -96.81) | rating: 5
# 75225 | IBERIABANK | location: (32.86, -96.8) | rating: 2.5
# 75225 | Frost Bank | location: (32.88, -96.77) | rating: 5
# 75225 | Chase Bank | location: (32.86, -96.81) | rating: 5
# 75225 | Simmons Bank | location: (32.86, -96.81) | rating: 3.8
# 75225 | Mike Dickstein: IBERIABANK Mortgage | location: (32.86, -96.81) | rating: 5
# 75225 | Guaranty Bank & Trust | location: (32.86, -96.81) | rating: 5
# 75225 | Tony Kruse: IBERIABANK Mortgage | location: (32.86, -96.81) | rating: 5
# 75225 | Ed Francis | location: (32.86, -96.81) | rating: 5
# 75225 | LegacyTexas | location: (32.85, -96.79) | rating: 3.8
# 75225 | GO Federal Credit Union - Corporate Office | location: (32.89, -96.77) | rating: 2.3
# 75225 | LegacyTexas | location: (32.89, -96.8) | rating: 4.2
# 75225 | Bank of Texas | location: (32.84, -96.79) | rating: 1
# 75225 | First Convenience Bank | location: (32.86, -96.75) | rating: 3.3
#
# Total number of banks found for 75225: 37 | rating_sum: 128.9 | avg_rating: 3.48
# ------------------------------------------------------------------------------------------------------
#
# 75201 | Comerica Bank | location: (32.78, -96.8) | rating: 3.4
# 75201 | Hillcrest Bank | location: (32.8, -96.81) | rating: 3.7
# 75201 | Bank of America Financial Center | location: (32.81, -96.81) | rating: 2.1
# 75201 | Wells Fargo Bank | location: (32.78, -96.8) | rating: 3.7
# 75201 | Comerica Bank | location: (32.79, -96.75) | rating: 3.7
# 75201 | Wells Fargo Bank | location: (32.8, -96.81) | rating: 3.9
# 75201 | PlainsCapital Bank | location: (32.8, -96.81) | rating: 4.5
# 75201 | PlainsCapital Bank | location: (32.79, -96.81) | rating: 5
# 75201 | First Citizens Bank | location: (32.8, -96.8) | rating: 3.4
# 75201 | BBVA Bank | location: (32.8, -96.81) | rating: 3.6
# 75201 | Capital One Bank | location: (32.79, -96.78) | rating: 3.5
# 75201 | Chase Bank | location: (32.81, -96.8) | rating: 3.9
# 75201 | Chase Bank | location: (32.82, -96.81) | rating: 1.8
# 75201 | Chase Bank | location: (32.81, -96.78) | rating: 2.7
# 75201 | Bank of America Financial Center | location: (32.78, -96.8) | rating: 2.4
# 75201 | Texas Security Bank | location: (32.79, -96.83) | rating: 5
# 75201 | Round Rock Capital Management | location: (32.8, -96.8) | rating: 5
# 75201 | Wells Fargo Bank | location: (32.79, -96.8) | rating: 3
# 75201 | Amegy Bank | location: (32.83, -96.78) | rating: 2.3
# 75201 | Chase Bank | location: (32.79, -96.8) | rating: 3.6
# 75201 | Independent Bankers Capital | location: (32.78, -96.8) | rating: 4.5
# 75201 | GO Federal Credit Union - Central Branch | location: (32.81, -96.79) | rating: 3.8
# 75201 | Chase Bank | location: (32.77, -96.84) | rating: 3.4
# 75201 | Bank of America Financial Center | location: (32.81, -96.79) | rating: 2.5
# 75201 | Providence Bank of Texas | location: (32.78, -96.8) | rating: 5
# 75201 | Comerica Bank | location: (32.79, -96.8) | rating: 2.8
# 75201 | Comerica Bank | location: (32.82, -96.79) | rating: 3.6
# 75201 | ATM (7-Eleven) | location: (32.81, -96.81) | rating: 4
# 75201 | PlainsCapital Bank | location: (32.78, -96.8) | rating: 4.5
# 75201 | Bank of Texas | location: (32.8, -96.78) | rating: 4.4
# 75201 | Belmont Wealth Management | location: (32.8, -96.81) | rating: 1
# 75201 | BB&T | location: (32.79, -96.8) | rating: 5
# 75201 | UMB Bank | location: (32.79, -96.8) | rating: 3.4
# 75201 | PlainsCapital Bank | location: (32.78, -96.8) | rating: 5
# 75201 | Advancial | location: (32.78, -96.8) | rating: 3
# 75201 | Chase Bank | location: (32.79, -96.8) | rating: 3
# 75201 | Advancial | location: (32.79, -96.8) | rating: 3.5
# 75201 | Regions Bank | location: (32.79, -96.8) | rating: 2.1
# 75201 | West Texas National Bank (WTNB) - Dallas Loan Production Office | location: (32.79, -96.8) | rating: 1
# 75201 | Amegy Bank | location: (32.79, -96.81) | rating: 4
# 75201 | Independent Bank | location: (32.79, -96.79) | rating: 3.7
# 75201 | LegacyTexas | location: (32.79, -96.81) | rating: 5
#
# Total number of banks found for 75201: 35 | rating_sum: 121.9 | avg_rating: 3.48
# ------------------------------------------------------------------------------------------------------
# 75209 | Chase Bank | location: (32.86, -96.84) | rating: 4.3
# 75209 | BBVA Bank | location: (32.86, -96.81) | rating: 4.2
# 75209 | Wells Fargo Bank | location: (32.85, -96.81) | rating: 4
# 75209 | Comerica Bank | location: (32.86, -96.8) | rating: 5
# 75209 | Comerica Bank | location: (32.85, -96.77) | rating: 3.2
# 75209 | Chase Bank | location: (32.82, -96.81) | rating: 1.8
# 75209 | Amegy Bank | location: (32.83, -96.78) | rating: 2.3
# 75209 | Regions Bank | location: (32.87, -96.81) | rating: 2.4
# 75209 | Frost Bank | location: (32.86, -96.8) | rating: 4.5
# 75209 | Bank of America Financial Center | location: (32.83, -96.83) | rating: 3
# 75209 | Inwood National Bank | location: (32.85, -96.82) | rating: 3.9
# 75209 | Bank of America Financial Center | location: (32.81, -96.81) | rating: 2.1
# 75209 | Cadence Trust | location: (32.86, -96.81) | rating: 5
# 75209 | Bank of Texas | location: (32.84, -96.79) | rating: 4.3
# 75209 | Bank of Texas | location: (32.85, -96.8) | rating: 4.4
# 75209 | Chase Bank | location: (32.86, -96.8) | rating: 3.9
# 75209 | Texas Capital Bank | location: (32.84, -96.78) | rating: 4.2
# 75209 | Chase Bank | location: (32.82, -96.85) | rating: 2.4
# 75209 | Wells Fargo Bank | location: (32.86, -96.8) | rating: 3
# 75209 | Pegasus Bank | location: (32.84, -96.83) | rating: 5
# 75209 | Beal Bank | location: (32.87, -96.81) | rating: 5
# 75209 | Nexbank | location: (32.86, -96.81) | rating: 3
# 75209 | Veritex Community Bank | location: (32.87, -96.8) | rating: 3
# 75209 | BB&T | location: (32.85, -96.82) | rating: 4.3
# 75209 | Washington Federal | location: (32.85, -96.82) | rating: 5
# 75209 | Tony Kruse: IBERIABANK Mortgage | location: (32.86, -96.81) | rating: 5
# 75209 | Ed Francis | location: (32.86, -96.81) | rating: 5
# 75209 | Mike Dickstein: IBERIABANK Mortgage | location: (32.86, -96.81) | rating: 5
# 75209 | Chase Bank | location: (32.86, -96.81) | rating: 5
# 75209 | Guaranty Bank & Trust | location: (32.86, -96.81) | rating: 5
# 75209 | Simmons Bank | location: (32.86, -96.81) | rating: 3.8
# 75209 | IBERIABANK | location: (32.86, -96.8) | rating: 2.5
# 75209 | Amegy Bank | location: (32.84, -96.83) | rating: 3.9
# 75209 | LegacyTexas | location: (32.85, -96.79) | rating: 3.8
# 75209 | Bank of America Financial Center | location: (32.84, -96.8) | rating: 2.6
# 75209 | Bank of Texas | location: (32.84, -96.79) | rating: 1
# 75209 | Comerica Bank | location: (32.87, -96.78) | rating: 1.8
# 75209 | Capital One Bank | location: (32.86, -96.86) | rating: 2.5
# 75209 | Bank of America Financial Center | location: (32.85, -96.77) | rating: 1.6
# 75209 | Bank of America Financial Center | location: (32.85, -96.79) | rating: 3.3
#
# Total number of banks found for 75209: 35 | rating_sum: 121.9 | avg_rating: 3.48
# ------------------------------------------------------------------------------------------------------
#
# 75230 | North Dallas Bank & Trust Co | location: (32.92, -96.8) | rating: 3.5
# 75230 | Chase Bank | location: (32.93, -96.8) | rating: 3.7
# 75230 | Bank of America Financial Center | location: (32.88, -96.76) | rating: 2
# 75230 | BBVA Bank | location: (32.86, -96.81) | rating: 4.2
# 75230 | Comerica Bank | location: (32.91, -96.82) | rating: 2
# 75230 | Comerica Bank | location: (32.86, -96.8) | rating: 5
# 75230 | Regions Bank | location: (32.87, -96.81) | rating: 2.4
# 75230 | Frost Bank | location: (32.86, -96.8) | rating: 4.5
# 75230 | BBVA Bank | location: (32.91, -96.77) | rating: 2.3
# 75230 | Bank of America Financial Center | location: (32.91, -96.74) | rating: 1.9
# 75230 | Wells Fargo Bank | location: (32.91, -96.8) | rating: 3.5
# 75230 | Comerica Bank | location: (32.87, -96.78) | rating: 1.8
# 75230 | Chase Bank | location: (32.89, -96.77) | rating: 2.5
# 75230 | LegacyTexas Bank | location: (32.91, -96.8) | rating: 5
# 75230 | AccessBank Texas | location: (32.93, -96.81) | rating: 3.4
# 75230 | LegacyTexas | location: (32.89, -96.8) | rating: 4.2
# 75230 | GO Federal Credit Union - Corporate Office | location: (32.89, -96.77) | rating: 2.3
# 75230 | Frost Bank | location: (32.88, -96.77) | rating: 5
# 75230 | United Texas Bank | location: (32.93, -96.8) | rating: 4.2
# 75230 | Washington Federal | location: (32.92, -96.82) | rating: 3.3
# 75230 | Wells Fargo Bank | location: (32.93, -96.77) | rating: 4.1
# 75230 | Bank of America Financial Center | location: (32.91, -96.8) | rating: 2.2
# 75230 | First Convenience Bank | location: (32.91, -96.75) | rating: 3.3
# 75230 | Chase Bank | location: (32.86, -96.8) | rating: 3.9
# 75230 | Veritex Community Bank | location: (32.87, -96.8) | rating: 3
# 75230 | Chase Bank | location: (32.86, -96.77) | rating: 2.7
# 75230 | Nexbank | location: (32.86, -96.81) | rating: 3
# 75230 | Wells Fargo Bank | location: (32.86, -96.8) | rating: 3
# 75230 | Beal Bank | location: (32.87, -96.81) | rating: 5
# 75230 | IBERIABANK | location: (32.86, -96.8) | rating: 2.5
# 75230 | Simmons Bank | location: (32.86, -96.81) | rating: 3.8
# 75230 | Wells Fargo Bank | location: (32.89, -96.74) | rating: 3.5
# 75230 | United Texas Bank | location: (32.91, -96.77) | rating: 1
# 75230 | BBVA Bank | location: (32.86, -96.77) | rating: 3.5
# 75230 | First Convenience Bank | location: (32.91, -96.74) | rating: 3.9
# 75230 | Chase Bank | location: (32.91, -96.8) | rating: 3.5
# 75230 | Chase Bank | location: (32.89, -96.8) | rating: 4
# 75230 | Guaranty Bank & Trust | location: (32.86, -96.81) | rating: 5
# 75230 | Bank of America Financial Center | location: (32.9, -96.8) | rating: 3
# 75230 | Amegy Bank | location: (32.87, -96.79) | rating: 5
# 75230 | Prosperity Bank | location: (32.91, -96.74) | rating: 3.1
# 75230 | Chase Bank | location: (32.91, -96.75) | rating: 3.8
#
# Total number of banks found for 75230: 40 | rating_sum: 135.0 | avg_rating: 3.38
# ------------------------------------------------------------------------------------------------------
#
# 75252 | Cathay Bank | location: (33.03, -96.77) | rating: 4.9
# 75252 | Capital One Bank | location: (33.01, -96.77) | rating: 3.6
# 75252 | Comerica Bank | location: (33.0, -96.83) | rating: 3.5
# 75252 | Comerica Bank | location: (33.01, -96.79) | rating: 4
# 75252 | Woodforest National Bank | location: (33.0, -96.77) | rating: 2.8
# 75252 | Bank of America Financial Center | location: (32.98, -96.77) | rating: 2.9
# 75252 | Bank of America Financial Center | location: (33.0, -96.83) | rating: 2.8
# 75252 | Bank of America Financial Center | location: (33.03, -96.77) | rating: 2.7
# 75252 | Beal Bank | location: (32.96, -96.82) | rating: 5
# 75252 | Bank of America Financial Center | location: (32.98, -96.8) | rating: 2.4
# 75252 | First National Bank of Omaha | location: (33.02, -96.79) | rating: 4.8
# 75252 | Regions Bank | location: (32.97, -96.82) | rating: 2.5
# 75252 | Wells Fargo Bank | location: (33.02, -96.79) | rating: 2.7
# 75252 | Comerica Bank | location: (33.03, -96.83) | rating: 3.7
# 75252 | Wells Fargo Bank | location: (33.0, -96.77) | rating: 4
# 75252 | Washington Federal | location: (32.98, -96.77) | rating: 4
# 75252 | Wells Fargo Bank | location: (33.0, -96.8) | rating: 3
# 75252 | SP Bancorp Inc | location: (33.02, -96.81) | rating: 3
# 75252 | PlainsCapital Bank | location: (33.0, -96.8) | rating: 3.4
# 75252 | LegacyTexas | location: (32.99, -96.83) | rating: 3
# 75252 | Chase Bank | location: (32.98, -96.77) | rating: 3.2
# 75252 | Chase Bank | location: (33.03, -96.77) | rating: 3.1
# 75252 | Stockmans Bank | location: (32.97, -96.82) | rating: 3.7
# 75252 | Veritex Community Bank | location: (32.98, -96.83) | rating: 4
# 75252 | LegacyTexas | location: (33.03, -96.82) | rating: 4.8
# 75252 | First Convenience Bank | location: (33.03, -96.83) | rating: 4.6
# 75252 | Bank of America Financial Center | location: (33.04, -96.79) | rating: 2.5
# 75252 | East West Bank | location: (33.03, -96.77) | rating: 3
# 75252 | Ocwen | location: (32.98, -96.83) | rating: 1
# 75252 | LegacyTexas | location: (32.98, -96.76) | rating: 2.8
# 75252 | Bank of America Financial Center | location: (33.0, -96.84) | rating: 1.9
# 75252 | RBFCU - Credit Union | location: (33.03, -96.83) | rating: 3.9
# 75252 | Wells Fargo Bank | location: (33.04, -96.79) | rating: 3.3
# 75252 | Wells Fargo Bank | location: (32.98, -96.77) | rating: 4.1
# 75252 | Independent Bank | location: (32.97, -96.82) | rating: 5
# 75252 | Independent Bank Mortgage | location: (32.97, -96.82) | rating: 1
# 75252 | Wells Fargo Bank | location: (33.0, -96.83) | rating: 3.4
# 75252 | First Convenience Bank | location: (33.0, -96.85) | rating: 3.6
# 75252 | DFW Mortgage Pros - Office of Nestor J Caussade Morales, Loan Officer | location: (32.97, -96.82) | rating: 5
# 75252 | Frost Bank | location: (33.03, -96.8) | rating: 3.7
# 75252 | Chase Bank | location: (33.0, -96.83) | rating: 2.9
# 75252 | BBVA Bank | location: (32.99, -96.8) | rating: 3.2
# 75252 | BB&T | location: (33.0, -96.77) | rating: 4.8
# 75252 | Capital One Bank | location: (32.99, -96.83) | rating: 3.3
# 75252 | Chase Bank | location: (33.03, -96.8) | rating: 2.7
# 75252 | Bank of Texas | location: (33.0, -96.77) | rating: 4.8
# 75252 | LegacyTexas Bank | location: (32.99, -96.83) | rating: 3.7
# 75252 | Chase Bank | location: (33.0, -96.8) | rating: 2.4
# 75252 | Wells Fargo Bank | location: (33.03, -96.83) | rating: 2.4
# 75252 | Liberty Capital Bank | location: (32.97, -96.82) | rating: 3.7
#
# Total number of banks found for 75252: 42 | rating_sum: 141.8 | avg_rating: 3.38
# ------------------------------------------------------------------------------------------------------
# 75229 | Wells Fargo Bank | location: (32.91, -96.86) | rating: 3
# 75229 | Chase Bank | location: (32.88, -96.88) | rating: 2.3
# 75229 | Bank of America Financial Center | location: (32.9, -96.87) | rating: 2.1
# 75229 | Chase Bank | location: (32.91, -96.86) | rating: 2.2
# 75229 | BBVA Bank | location: (32.86, -96.87) | rating: 4.2
# 75229 | American First National Bank | location: (32.89, -96.89) | rating: 1.6
# 75229 | Shinhan Bank America | location: (32.9, -96.91) | rating: 4.5
# 75229 | American Bank | location: (32.86, -96.88) | rating: 3.6
# 75229 | Comerica Bank | location: (32.91, -96.87) | rating: 2.3
# 75229 | State Bank of Texas | location: (32.91, -96.87) | rating: 3
# 75229 | BB&T | location: (32.91, -96.86) | rating: 1.4
# 75229 | Shinhan Bank America Texas Loan Center | location: (32.9, -96.9) | rating: 5
# 75229 | Commonwealth Business Bank (CBB Bank) | location: (32.9, -96.91) | rating: 5
# 75229 | First Convenience Bank | location: (32.92, -96.84) | rating: 2.4
# 75229 | Capital One Bank | location: (32.86, -96.86) | rating: 2.5
# 75229 | Wells Fargo Bank | location: (32.93, -96.88) | rating: 3.5
# 75229 | Chase Bank | location: (32.92, -96.88) | rating: 2.9
# 75229 | Simmons Bank | location: (32.91, -96.92) | rating: 3
# 75229 | Capital One Bank | location: (32.91, -96.88) | rating: 4.1
# 75229 | Bank of America Financial Center | location: (32.88, -96.86) | rating: 2.2
# 75229 | Bank of Texas | location: (32.89, -96.89) | rating: 4.4
# 75229 | Bank of Hope | location: (32.9, -96.9) | rating: 3.2
# 75229 | One World Bank | location: (32.88, -96.89) | rating: 3.3
# 75229 | East West Bank | location: (32.9, -96.89) | rating: 5
# 75229 | BBVA Bank | location: (32.86, -96.9) | rating: 3.7
# 75229 | Hanmi Bank | location: (32.89, -96.89) | rating: 5
# 75229 | Wallis Bank | location: (32.89, -96.89) | rating: 5
# 75229 | The Netland Corporation | location: (32.91, -96.89) | rating: 5
# 75229 | Wells Fargo Bank | location: (32.93, -96.84) | rating: 3.7
# 75229 | Spectra Bank | location: (32.86, -96.89) | rating: 5
# 75229 | First Convenience Bank | location: (32.92, -96.84) | rating: 1.2
# 75229 | FHLB DATA CENTER | location: (32.9, -96.92) | rating: 5
# 75229 | Cardtronics ATM | location: (32.86, -96.89) | rating: 5
# 75229 | BBVA Dallas Creation Center | location: (32.9, -96.92) | rating: 5
#
# Total number of banks found for 75229: 29 | rating_sum: 98.9 | avg_rating: 3.41
# ------------------------------------------------------------------------------------------------------
#
# 75220 | Chase Bank | location: (32.86, -96.84) | rating: 4.3
# 75220 | Power Finance Texas | location: (32.83, -96.87) | rating: 3.9
# 75220 | Chase Bank | location: (32.88, -96.88) | rating: 2.3
# 75220 | Bank of America Financial Center | location: (32.9, -96.87) | rating: 2.1
# 75220 | BBVA Bank | location: (32.86, -96.87) | rating: 4.2
# 75220 | American Bank | location: (32.86, -96.88) | rating: 3.6
# 75220 | American First National Bank | location: (32.89, -96.89) | rating: 1.6
# 75220 | Capital One Bank | location: (32.86, -96.86) | rating: 2.5
# 75220 | Shinhan Bank America | location: (32.9, -96.91) | rating: 4.5
# 75220 | Regions Bank | location: (32.82, -96.87) | rating: 2.6
# 75220 | Washington Federal | location: (32.85, -96.82) | rating: 5
# 75220 | Bank of America Financial Center | location: (32.88, -96.86) | rating: 2.2
# 75220 | Wells Fargo Bank | location: (32.82, -96.86) | rating: 2.6
# 75220 | Shinhan Bank America Texas Loan Center | location: (32.9, -96.9) | rating: 5
# 75220 | BBVA Bank | location: (32.86, -96.9) | rating: 3.7
# 75220 | Comerica Bank | location: (32.82, -96.87) | rating: 5
# 75220 | Bank of Texas | location: (32.89, -96.89) | rating: 4.4
# 75220 | Commonwealth Business Bank (CBB Bank) | location: (32.9, -96.91) | rating: 5
# 75220 | Wells Fargo Bank | location: (32.82, -96.86) | rating: 4.3
# 75220 | One World Bank | location: (32.88, -96.89) | rating: 3.3
# 75220 | Cardtronics ATM | location: (32.86, -96.89) | rating: 5
# 75220 | Spectra Bank | location: (32.86, -96.89) | rating: 5
# 75220 | Wallis Bank | location: (32.89, -96.89) | rating: 5
# 75220 | Hanmi Bank | location: (32.89, -96.89) | rating: 5
# 75220 | East West Bank | location: (32.9, -96.89) | rating: 5
# 75220 | BB&T | location: (32.82, -96.87) | rating: 3.6
# 75220 | Bank of Hope | location: (32.9, -96.9) | rating: 3.2
# 75220 | Comerica Bank | location: (32.82, -96.86) | rating: 3
# 75220 | washington federal, Lovers Lane | location: (32.85, -96.82) | rating: 1
#
# Total number of banks found for 75220: 24 | rating_sum: 89.4 | avg_rating: 3.72
# ------------------------------------------------------------------------------------------------------
#
# 75214 | Comerica Bank | location: (32.79, -96.75) | rating: 3.7
# 75214 | Comerica Bank | location: (32.85, -96.77) | rating: 3.2
# 75214 | Wells Fargo Bank | location: (32.84, -96.75) | rating: 4.4
# 75214 | Comerica Bank | location: (32.82, -96.75) | rating: 3.3
# 75214 | Amegy Bank | location: (32.83, -96.78) | rating: 2.3
# 75214 | Comerica Bank | location: (32.86, -96.74) | rating: 2.3
# 75214 | Chase Bank | location: (32.81, -96.78) | rating: 2.7
# 75214 | Wells Fargo Bank | location: (32.81, -96.75) | rating: 3.7
# 75214 | BBVA Bank | location: (32.81, -96.75) | rating: 3.7
# 75214 | Texas Capital Bank | location: (32.84, -96.78) | rating: 4.2
# 75214 | Capital One Bank | location: (32.79, -96.78) | rating: 3.5
# 75214 | Capital One Bank | location: (32.86, -96.76) | rating: 2.4
# 75214 | Veritex Community Bank | location: (32.82, -96.75) | rating: 3.3
# 75214 | Bank of America Financial Center | location: (32.85, -96.77) | rating: 1.6
# 75214 | Wells Fargo Bank | location: (32.85, -96.77) | rating: 3.2
# 75214 | Comerica Bank | location: (32.84, -96.76) | rating: 5
# 75214 | Bank of Texas | location: (32.84, -96.79) | rating: 4.3
# 75214 | BBVA Bank | location: (32.83, -96.7) | rating: 3
# 75214 | Frost Bank | location: (32.81, -96.75) | rating: 4.8
# 75214 | GO Federal Credit Union - Central Branch | location: (32.81, -96.79) | rating: 3.8
# 75214 | Veritex Community Bank | location: (32.84, -96.77) | rating: 5
# 75214 | Chase Bank | location: (32.84, -96.77) | rating: 3
# 75214 | UMB Bank | location: (32.82, -96.79) | rating: 5
# 75214 | Bank of America Financial Center | location: (32.84, -96.75) | rating: 4
# 75214 | Bank of Texas | location: (32.8, -96.78) | rating: 4.4
# 75214 | First Convenience Bank | location: (32.86, -96.75) | rating: 3.3
# 75214 | Chase Bank | location: (32.86, -96.77) | rating: 2.7
# 75214 | Bank of America Financial Center | location: (32.81, -96.79) | rating: 2.5
# 75214 | Comerica Bank | location: (32.82, -96.79) | rating: 3.6
# 75214 | Wells Fargo Bank | location: (32.83, -96.7) | rating: 3
# 75214 | Chase Bank | location: (32.84, -96.75) | rating: 4.3
# 75214 | BBVA Bank | location: (32.86, -96.77) | rating: 3.5
# 75214 | InterBank | location: (32.84, -96.78) | rating: 3.2
# 75214 | Bank of Texas | location: (32.84, -96.79) | rating: 1
# 75214 | Bank of America Financial Center | location: (32.81, -96.76) | rating: 2.7
# 75214 | Chase Bank | location: (32.83, -96.7) | rating: 2.9
# 75214 | BBVA Bank | location: (32.84, -96.76) | rating: 2.5
# 75214 | Cardtronics | location: (32.81, -96.77) | rating: 5
# 75214 | Bank of America Financial Center | location: (32.79, -96.78) | rating: 2.2
# 75214 | BB&T | location: (32.82, -96.77) | rating: 4.5
# 75214 | BBVA Bank | location: (32.85, -96.79) | rating: 4.4
# 75214 | Bank of America Financial Center | location: (32.86, -96.76) | rating: 3
# 75214 | Wells Fargo Bank | location: (32.81, -96.77) | rating: 5
# 75214 | Navy Federal Credit Union | location: (32.86, -96.75) | rating: 4.6
# 75214 | Chase Bank | location: (32.86, -96.75) | rating: 2.9
# 75214 | Citibank ATM | location: (32.82, -96.79) | rating: 1
#
# Total number of banks found for 75214: 44 | rating_sum: 148.1 | avg_rating: 3.37
# ------------------------------------------------------------------------------------------------------
#
# 75039 | Bank of America Financial Center | location: (32.91, -96.96) | rating: 2
# 75039 | Capital One Bank | location: (32.87, -96.95) | rating: 3.5
# 75039 | Comerica Bank | location: (32.89, -96.96) | rating: 4.2
# 75039 | Wells Fargo Bank | location: (32.92, -96.96) | rating: 3.4
# 75039 | Capital One Bank | location: (32.92, -96.96) | rating: 3
# 75039 | Comerica Bank | location: (32.87, -96.99) | rating: 2.3
# 75039 | Bank of America Financial Center | location: (32.87, -96.94) | rating: 2.8
# 75039 | BBVA Bank | location: (32.91, -96.96) | rating: 2.6
# 75039 | Chase Bank | location: (32.92, -96.96) | rating: 4
# 75039 | Bank of America Financial Center | location: (32.88, -96.96) | rating: 2.6
# 75039 | Wells Fargo Bank | location: (32.86, -96.96) | rating: 3.5
# 75039 | BB&T | location: (32.9, -96.96) | rating: 4.1
# 75039 | Shinhan Bank America | location: (32.9, -96.91) | rating: 4.5
# 75039 | Bank7 | location: (32.9, -96.96) | rating: 5
# 75039 | Chase Bank | location: (32.89, -96.96) | rating: 3.3
# 75039 | Regions Bank | location: (32.91, -96.95) | rating: 3.2
# 75039 | First Convenience Bank | location: (32.91, -96.96) | rating: 2.1
# 75039 | Origin Bank | location: (32.91, -96.96) | rating: 5
# 75039 | Southside Bank | location: (32.89, -96.97) | rating: 2.6
# 75039 | Simmons Bank | location: (32.91, -96.92) | rating: 3
# 75039 | Credit Union of Texas | location: (32.89, -96.98) | rating: 3.4
# 75039 | First Convenience Bank | location: (32.92, -96.97) | rating: 1.8
# 75039 | ATM Wal-mart | location: (32.92, -96.97) | rating: 4
# 75039 | Chase Bank | location: (32.86, -96.93) | rating: 4.2
# 75039 | Commonwealth Business Bank (CBB Bank) | location: (32.9, -96.91) | rating: 5
# 75039 | Shinhan Bank America Texas Loan Center | location: (32.9, -96.9) | rating: 5
# 75039 | BBVA Bank | location: (32.87, -96.95) | rating: 3.7
# 75039 | Veritex Bank | location: (32.87, -96.99) | rating: 5
# 75039 | Bank of America Mortgage | location: (32.86, -96.93) | rating: 5
# 75039 | Chase Bank | location: (32.91, -96.96) | rating: 3.6
# 75039 | North Dallas Bank & Trust Co | location: (32.91, -96.96) | rating: 3.7
# 75039 | Bank of Hope | location: (32.9, -96.9) | rating: 3.2
# 75039 | Citi Dallas | location: (32.9, -96.95) | rating: 5
# 75039 | BBVA Dallas Creation Center | location: (32.9, -96.92) | rating: 5
# 75039 | FHLB DATA CENTER | location: (32.9, -96.92) | rating: 5
# 75039 | Planet Home Lending | location: (32.86, -96.93) | rating: 5
# 75039 | Wells Fargo Lockbox | location: (32.92, -96.98) | rating: 5
#
# Total number of banks found for 75039: 30 | rating_sum: 106.2 | avg_rating: 3.54
# ------------------------------------------------------------------------------------------------------
#
# 75019 | Comerica Bank | location: (32.97, -96.99) | rating: 2.3
# 75019 | Chase Bank | location: (32.98, -96.99) | rating: 2.9
# 75019 | Amegy Bank | location: (32.92, -96.99) | rating: 4
# 75019 | LegacyTexas | location: (32.99, -96.99) | rating: 4
# 75019 | TIAA Financial Services | location: (32.99, -96.96) | rating: 2.9
# 75019 | Bank of America Financial Center | location: (32.95, -96.96) | rating: 2
# 75019 | Mobility Credit Union | location: (32.92, -96.99) | rating: 3.3
# 75019 | BB&T | location: (32.97, -96.99) | rating: 3.8
# 75019 | Wells Fargo Bank | location: (32.97, -96.99) | rating: 3.4
# 75019 | First Convenience Bank | location: (33.0, -96.99) | rating: 3.9
# 75019 | Bank of America Financial Center | location: (32.99, -96.99) | rating: 2.6
# 75019 | Chase Bank | location: (32.94, -96.99) | rating: 2.6
# 75019 | Capital One Bank | location: (32.99, -96.97) | rating: 2.4
# 75019 | Frost Bank | location: (32.97, -96.99) | rating: 3.8
# 75019 | Independent Bank | location: (32.98, -96.99) | rating: 3.7
# 75019 | Chase Bank | location: (32.97, -96.96) | rating: 4.3
# 75019 | Bank of Texas | location: (32.99, -96.97) | rating: 5
# 75019 | Federal Home Loan Bank | location: (32.92, -97.02) | rating: 5
# 75019 | Bank OZK | location: (33.0, -96.99) | rating: 3
#
# Total number of banks found for 75019: 16 | rating_sum: 54.2 | avg_rating: 3.39
# ------------------------------------------------------------------------------------------------------
#
# 75244 | Frost Bank | location: (32.96, -96.82) | rating: 3.5
# 75244 | North Dallas Bank & Trust Co | location: (32.92, -96.8) | rating: 3.5
# 75244 | Chase Bank | location: (32.94, -96.82) | rating: 3.5
# 75244 | Comerica Bank | location: (32.94, -96.84) | rating: 2.8
# 75244 | Chase Bank | location: (32.93, -96.8) | rating: 3.7
# 75244 | Beal Bank | location: (32.96, -96.82) | rating: 5
# 75244 | Wells Fargo Bank | location: (32.91, -96.86) | rating: 3
# 75244 | Comerica Bank | location: (32.91, -96.82) | rating: 2
# 75244 | Bank of America Financial Center | location: (32.95, -96.82) | rating: 2.5
# 75244 | Capital One Bank | location: (32.95, -96.81) | rating: 2.6
# 75244 | Wells Fargo Bank | location: (32.95, -96.8) | rating: 3.1
# 75244 | Capital One Bank | location: (32.93, -96.84) | rating: 4.3
# 75244 | Mutual of Omaha Bank | location: (32.95, -96.8) | rating: 5
# 75244 | Chase Bank | location: (32.91, -96.86) | rating: 2.2
# 75244 | Supreme Mortgage Company Dallas TX | location: (32.95, -96.82) | rating: 5
# 75244 | BBVA Bank | location: (32.94, -96.85) | rating: 4.4
# 75244 | First Convenience Bank | location: (32.92, -96.84) | rating: 2.4
# 75244 | Bank of America Financial Center | location: (32.95, -96.81) | rating: 1.9
# 75244 | AccessBank Texas | location: (32.93, -96.81) | rating: 3.4
# 75244 | Washington Federal | location: (32.92, -96.82) | rating: 3.3
# 75244 | Wells Fargo Bank | location: (32.91, -96.8) | rating: 3.5
# 75244 | Jordan O'Brien, Mortgage Loan Originator | location: (32.94, -96.82) | rating: 5
# 75244 | Spirit of Texas Bank | location: (32.94, -96.82) | rating: 3.7
# 75244 | Comerica Bank | location: (32.95, -96.82) | rating: 3
# 75244 | LegacyTexas | location: (32.95, -96.83) | rating: 3.9
# 75244 | BB&T | location: (32.95, -96.85) | rating: 3.9
# 75244 | BB&T | location: (32.91, -96.86) | rating: 1.4
# 75244 | First American Bank | location: (32.96, -96.84) | rating: 1
# 75244 | United Texas Bank | location: (32.93, -96.8) | rating: 4.2
# 75244 | Texas Security Bank | location: (32.95, -96.87) | rating: 3.7
# 75244 | State Bank of Texas | location: (32.91, -96.87) | rating: 3
# 75244 | Comerica Bank | location: (32.91, -96.87) | rating: 2.3
# 75244 | Veritex Bank | location: (32.95, -96.8) | rating: 3.7
# 75244 | First Convenience Bank | location: (32.96, -96.82) | rating: 3
# 75244 | LegacyTexas Bank | location: (32.91, -96.8) | rating: 5
# 75244 | Usaa | location: (32.96, -96.82) | rating: 3.6
# 75244 | DFW Mortgage Pros - Office of Nestor J Caussade Morales, Loan Officer | location: (32.97, -96.82) | rating: 5
# 75244 | Chase Bank | location: (32.94, -96.86) | rating: 3.1
# 75244 | ATM Mutual Of Omaha Bank | location: (32.95, -96.8) | rating: 5
# 75244 | Independent Bank Mortgage | location: (32.97, -96.82) | rating: 1
# 75244 | Independent Bank | location: (32.97, -96.82) | rating: 5
# 75244 | Wells Fargo Bank | location: (32.95, -96.85) | rating: 3.8
# 75244 | Wells Fargo Bank | location: (32.93, -96.88) | rating: 3.5
# 75244 | Bank of America Financial Center | location: (32.91, -96.8) | rating: 2.2
# 75244 | Wells Fargo Bank | location: (32.95, -96.86) | rating: 2.9
# 75244 | Chase Bank | location: (32.92, -96.88) | rating: 2.9
#
# Total number of banks found for 75244: 38 | rating_sum: 124.3 | avg_rating: 3.27
# ------------------------------------------------------------------------------------------------------
#
# 75248 | Frost Bank | location: (32.96, -96.82) | rating: 3.5
# 75248 | Beal Bank | location: (32.96, -96.82) | rating: 5
# 75248 | Capital One Bank | location: (33.01, -96.77) | rating: 3.6
# 75248 | Wells Fargo Bank | location: (32.95, -96.8) | rating: 3.1
# 75248 | Mutual of Omaha Bank | location: (32.95, -96.8) | rating: 5
# 75248 | Bank of America Financial Center | location: (32.98, -96.77) | rating: 2.9
# 75248 | Comerica Bank | location: (33.01, -96.79) | rating: 4
# 75248 | Woodforest National Bank | location: (33.0, -96.77) | rating: 2.8
# 75248 | Capital One Bank | location: (32.95, -96.81) | rating: 2.6
# 75248 | Bank of America Financial Center | location: (32.98, -96.8) | rating: 2.4
# 75248 | Bank of America Financial Center | location: (32.95, -96.82) | rating: 2.5
# 75248 | Regions Bank | location: (32.97, -96.82) | rating: 2.5
# 75248 | Washington Federal | location: (32.98, -96.77) | rating: 4
# 75248 | Wells Fargo Bank | location: (33.0, -96.77) | rating: 4
# 75248 | Wells Fargo Bank | location: (33.0, -96.8) | rating: 3
# 75248 | Bank of America Financial Center | location: (32.96, -96.75) | rating: 2.2
# 75248 | Bank of America Financial Center | location: (32.95, -96.81) | rating: 1.9
# 75248 | Veritex Bank | location: (32.95, -96.8) | rating: 3.7
# 75248 | Chase Bank | location: (32.98, -96.77) | rating: 3.2
# 75248 | LegacyTexas | location: (32.98, -96.76) | rating: 2.8
# 75248 | ATM Mutual Of Omaha Bank | location: (32.95, -96.8) | rating: 5
# 75248 | PlainsCapital Bank | location: (33.0, -96.8) | rating: 3.4
# 75248 | Texas Republic Bank | location: (32.98, -96.74) | rating: 3.6
# 75248 | Stockmans Bank | location: (32.97, -96.82) | rating: 3.7
# 75248 | First Convenience Bank | location: (32.96, -96.82) | rating: 3
# 75248 | Independent Bank Mortgage | location: (32.97, -96.82) | rating: 1
# 75248 | Independent Bank | location: (32.97, -96.82) | rating: 5
# 75248 | DFW Mortgage Pros - Office of Nestor J Caussade Morales, Loan Officer | location: (32.97, -96.82) | rating: 5
# 75248 | Usaa | location: (32.96, -96.82) | rating: 3.6
# 75248 | Wells Fargo Bank | location: (32.98, -96.77) | rating: 4.1
# 75248 | Supreme Mortgage Company Dallas TX | location: (32.95, -96.82) | rating: 5
# 75248 | BB&T | location: (32.95, -96.8) | rating: 3
# 75248 | Chase Bank | location: (32.95, -96.77) | rating: 3.3
# 75248 | Veritex Community Bank | location: (32.98, -96.83) | rating: 4
# 75248 | Wells Fargo Bank | location: (32.96, -96.77) | rating: 4.3
# 75248 | BBVA Bank | location: (32.95, -96.8) | rating: 1.7
# 75248 | BBVA Bank | location: (32.99, -96.8) | rating: 3.2
# 75248 | BBVA Bank | location: (32.95, -96.77) | rating: 2.1
# 75248 | Liberty Capital Bank | location: (32.97, -96.82) | rating: 3.7
# 75248 | Prestige Community Credit Union | location: (32.96, -96.82) | rating: 4.3
# 75248 | BB&T | location: (33.0, -96.77) | rating: 4.8
# 75248 | Ocwen | location: (32.98, -96.83) | rating: 1
# 75248 | Bank of Texas | location: (33.0, -96.77) | rating: 4.8
# 75248 | North Dallas Bank & Trust Co | location: (32.97, -96.82) | rating: 4
# 75248 | Wells Fargo Bank | location: (32.96, -96.82) | rating: 2.1
# 75248 | Chase Bank | location: (33.0, -96.8) | rating: 2.4
# 75248 | Pavillion Bank | location: (32.98, -96.76) | rating: 3.7
# 75248 | Comerica Bank | location: (32.95, -96.82) | rating: 3
# 75248 | Wells Fargo Bank | location: (32.98, -96.8) | rating: 3.7
#
# Total number of banks found for 75248: 41 | rating_sum: 137.0 | avg_rating: 3.34
# ------------------------------------------------------------------------------------------------------
#
# 75182 | Prosperity Bank | location: (32.8, -96.6) | rating: 3.2
#
# Total number of banks found for 75182: 1 | rating_sum: 3.2 | avg_rating: 3.2
# ------------------------------------------------------------------------------------------------------
#
# 75206 | Hillcrest Bank | location: (32.8, -96.81) | rating: 3.7
# 75206 | Comerica Bank | location: (32.85, -96.77) | rating: 3.2
# 75206 | Bank of America Financial Center | location: (32.81, -96.81) | rating: 2.1
# 75206 | Comerica Bank | location: (32.79, -96.75) | rating: 3.7
# 75206 | Wells Fargo Bank | location: (32.84, -96.75) | rating: 4.4
# 75206 | Amegy Bank | location: (32.83, -96.78) | rating: 2.3
# 75206 | Wells Fargo Bank | location: (32.8, -96.81) | rating: 3.9
# 75206 | Comerica Bank | location: (32.82, -96.75) | rating: 3.3
# 75206 | PlainsCapital Bank | location: (32.8, -96.81) | rating: 4.5
# 75206 | First Citizens Bank | location: (32.8, -96.8) | rating: 3.4
# 75206 | Chase Bank | location: (32.82, -96.81) | rating: 1.8
# 75206 | Chase Bank | location: (32.81, -96.8) | rating: 3.9
# 75206 | Capital One Bank | location: (32.79, -96.78) | rating: 3.5
# 75206 | Chase Bank | location: (32.81, -96.78) | rating: 2.7
# 75206 | BBVA Bank | location: (32.8, -96.81) | rating: 3.6
# 75206 | Wells Fargo Bank | location: (32.85, -96.81) | rating: 4
# 75206 | Wells Fargo Bank | location: (32.81, -96.75) | rating: 3.7
# 75206 | Round Rock Capital Management | location: (32.8, -96.8) | rating: 5
# 75206 | Texas Capital Bank | location: (32.84, -96.78) | rating: 4.2
# 75206 | Wells Fargo Bank | location: (32.79, -96.8) | rating: 3
# 75206 | BBVA Bank | location: (32.81, -96.75) | rating: 3.7
# 75206 | Bank of Texas | location: (32.84, -96.79) | rating: 4.3
# 75206 | Bank of America Financial Center | location: (32.85, -96.77) | rating: 1.6
# 75206 | GO Federal Credit Union - Central Branch | location: (32.81, -96.79) | rating: 3.8
# 75206 | Wells Fargo Bank | location: (32.85, -96.77) | rating: 3.2
# 75206 | Bank of Texas | location: (32.85, -96.8) | rating: 4.4
# 75206 | Chase Bank | location: (32.79, -96.8) | rating: 3.6
# 75206 | Veritex Community Bank | location: (32.82, -96.75) | rating: 3.3
# 75206 | Bank of America Financial Center | location: (32.81, -96.79) | rating: 2.5
# 75206 | Bank of America Financial Center | location: (32.83, -96.83) | rating: 3
# 75206 | Comerica Bank | location: (32.84, -96.76) | rating: 5
# 75206 | Comerica Bank | location: (32.82, -96.79) | rating: 3.6
# 75206 | Comerica Bank | location: (32.79, -96.8) | rating: 2.8
# 75206 | Capital One Bank | location: (32.86, -96.76) | rating: 2.4
# 75206 | Frost Bank | location: (32.81, -96.75) | rating: 4.8
# 75206 | Bank of Texas | location: (32.8, -96.78) | rating: 4.4
# 75206 | UMB Bank | location: (32.82, -96.79) | rating: 5
# 75206 | Veritex Community Bank | location: (32.84, -96.77) | rating: 5
# 75206 | Bank of Texas | location: (32.84, -96.79) | rating: 1
# 75206 | Origin Bank | location: (32.81, -96.8) | rating: 5
# 75206 | Belmont Wealth Management | location: (32.8, -96.81) | rating: 1
# 75206 | First Convenience Bank | location: (32.8, -96.79) | rating: 3.2
# 75206 | LegacyTexas | location: (32.85, -96.79) | rating: 3.8
# 75206 | Bank of America Financial Center | location: (32.84, -96.8) | rating: 2.6
#
# Total number of banks found for 75206: 41 | rating_sum: 143.1 | avg_rating: 3.49
# ------------------------------------------------------------------------------------------------------
#
# 75238 | Comerica Bank | location: (32.86, -96.74) | rating: 2.3
# 75238 | Wells Fargo Bank | location: (32.91, -96.7) | rating: 2.5
# 75238 | Bank of America Financial Center | location: (32.88, -96.76) | rating: 2
# 75238 | Bank of America Financial Center | location: (32.91, -96.74) | rating: 1.9
# 75238 | Chase Bank | location: (32.91, -96.73) | rating: 3.5
# 75238 | BBVA Bank | location: (32.9, -96.72) | rating: 2.5
# 75238 | Frost Bank | location: (32.91, -96.7) | rating: 3.7
# 75238 | Capital One Bank | location: (32.86, -96.76) | rating: 2.4
# 75238 | Comerica Bank | location: (32.91, -96.7) | rating: 1.8
# 75238 | Chase Bank | location: (32.88, -96.72) | rating: 3.9
# 75238 | LegacyTexas | location: (32.88, -96.72) | rating: 3
# 75238 | Legacy Bank Texas | location: (32.88, -96.72) | rating: 4
# 75238 | Wells Fargo Bank | location: (32.89, -96.74) | rating: 3.5
# 75238 | Comerica Bank | location: (32.85, -96.69) | rating: 3.8
# 75238 | Texas Brand Bank | location: (32.89, -96.67) | rating: 3.5
# 75238 | First Convenience Bank | location: (32.91, -96.74) | rating: 3.9
# 75238 | LegacyTexas | location: (32.88, -96.72) | rating: 3.4
# 75238 | Prosperity Bank | location: (32.91, -96.74) | rating: 3.1
# 75238 | First Convenience Bank | location: (32.91, -96.75) | rating: 3.3
# 75238 | First Convenience Bank | location: (32.86, -96.75) | rating: 3.3
# 75238 | Convenience Bank | location: (32.92, -96.72) | rating: 5
# 75238 | BB&T | location: (32.91, -96.7) | rating: 3.1
# 75238 | American First National Bank | location: (32.92, -96.68) | rating: 1.5
# 75238 | Wells Fargo Bank | location: (32.87, -96.74) | rating: 3.5
# 75238 | Chase Bank | location: (32.86, -96.75) | rating: 2.9
# 75238 | Integrity Mortgage Corporation of Texas | location: (32.9, -96.72) | rating: 4.9
# 75238 | ATM 7ELEVEN, INC. | location: (32.88, -96.72) | rating: 5
# 75238 | ATM 7ELEVEN, INC. | location: (32.88, -96.7) | rating: 5
# 75238 | Bbva Compass | location: (32.9, -96.72) | rating: 2.5
# 75238 | Chase Bank | location: (32.91, -96.75) | rating: 3.8
# 75238 | Bank of America Financial Center | location: (32.86, -96.76) | rating: 3
# 75238 | Navy Federal Credit Union | location: (32.86, -96.75) | rating: 4.6
# 75238 | Bank of Texas | location: (32.88, -96.76) | rating: 4.7
# 75238 | Sam's Nail Supply | location: (32.92, -96.72) | rating: 5
#
# Total number of banks found for 75238: 26 | rating_sum: 83.9 | avg_rating: 3.23
# ------------------------------------------------------------------------------------------------------
#
# 75219 | Comerica Bank | location: (32.78, -96.8) | rating: 3.4
# 75219 | Hillcrest Bank | location: (32.8, -96.81) | rating: 3.7
# 75219 | Bank of America Financial Center | location: (32.81, -96.81) | rating: 2.1
# 75219 | Wells Fargo Bank | location: (32.78, -96.8) | rating: 3.7
# 75219 | Wells Fargo Bank | location: (32.8, -96.81) | rating: 3.9
# 75219 | Amegy Bank | location: (32.83, -96.78) | rating: 2.3
# 75219 | PlainsCapital Bank | location: (32.8, -96.81) | rating: 4.5
# 75219 | PlainsCapital Bank | location: (32.79, -96.81) | rating: 5
# 75219 | First Citizens Bank | location: (32.8, -96.8) | rating: 3.4
# 75219 | Chase Bank | location: (32.82, -96.81) | rating: 1.8
# 75219 | BBVA Bank | location: (32.8, -96.81) | rating: 3.6
# 75219 | Chase Bank | location: (32.81, -96.8) | rating: 3.9
# 75219 | Capital One Bank | location: (32.79, -96.78) | rating: 3.5
# 75219 | Chase Bank | location: (32.81, -96.78) | rating: 2.7
# 75219 | Bank of America Financial Center | location: (32.83, -96.83) | rating: 3
# 75219 | Wells Fargo Bank | location: (32.85, -96.81) | rating: 4
# 75219 | Texas Security Bank | location: (32.79, -96.83) | rating: 5
# 75219 | Round Rock Capital Management | location: (32.8, -96.8) | rating: 5
# 75219 | Wells Fargo Bank | location: (32.79, -96.8) | rating: 3
# 75219 | Bank of America Financial Center | location: (32.78, -96.8) | rating: 2.4
# 75219 | Chase Bank | location: (32.79, -96.8) | rating: 3.6
# 75219 | Inwood National Bank | location: (32.85, -96.82) | rating: 3.9
# 75219 | Chase Bank | location: (32.82, -96.85) | rating: 2.4
# 75219 | Independent Bankers Capital | location: (32.78, -96.8) | rating: 4.5
# 75219 | GO Federal Credit Union - Central Branch | location: (32.81, -96.79) | rating: 3.8
# 75219 | Bank of Texas | location: (32.84, -96.79) | rating: 4.3
# 75219 | Bank of Texas | location: (32.85, -96.8) | rating: 4.4
# 75219 | Bank of America Financial Center | location: (32.81, -96.79) | rating: 2.5
# 75219 | Providence Bank of Texas | location: (32.78, -96.8) | rating: 5
# 75219 | Texas Capital Bank | location: (32.84, -96.78) | rating: 4.2
# 75219 | Comerica Bank | location: (32.79, -96.8) | rating: 2.8
# 75219 | Comerica Bank | location: (32.82, -96.79) | rating: 3.6
# 75219 | Pegasus Bank | location: (32.84, -96.83) | rating: 5
# 75219 | ATM (7-Eleven) | location: (32.81, -96.81) | rating: 4
# 75219 | Belmont Wealth Management | location: (32.8, -96.81) | rating: 1
# 75219 | First Convenience Bank | location: (32.81, -96.81) | rating: 4.3
# 75219 | Veritex Bank | location: (32.81, -96.81) | rating: 3
# 75219 | IBC Bank | location: (32.8, -96.81) | rating: 4.3
# 75219 | Origin Bank | location: (32.81, -96.8) | rating: 5
# 75219 | Midwest Regional Bank | location: (32.8, -96.8) | rating: 3
# 75219 | BB&T | location: (32.8, -96.8) | rating: 2.6
# 75219 | Frost Bank | location: (32.8, -96.81) | rating: 4.3
# 75219 | Commerce Bank - Commercial Banking Office | location: (32.79, -96.81) | rating: 3.3
#
# Total number of banks found for 75219: 39 | rating_sum: 142.1 | avg_rating: 3.64
# ------------------------------------------------------------------------------------------------------
#
# 75063 | Bank of America Financial Center | location: (32.91, -96.96) | rating: 2
# 75063 | Comerica Bank | location: (32.89, -96.96) | rating: 4.2
# 75063 | Wells Fargo Bank | location: (32.92, -96.96) | rating: 3.4
# 75063 | Comerica Bank | location: (32.87, -96.99) | rating: 2.3
# 75063 | Capital One Bank | location: (32.92, -96.96) | rating: 3
# 75063 | Mobility Credit Union | location: (32.92, -96.99) | rating: 3.3
# 75063 | BBVA Bank | location: (32.91, -96.96) | rating: 2.6
# 75063 | Amegy Bank | location: (32.92, -96.99) | rating: 4
# 75063 | Chase Bank | location: (32.92, -96.96) | rating: 4
# 75063 | BB&T | location: (32.9, -96.96) | rating: 4.1
# 75063 | Bank of America Financial Center | location: (32.88, -96.96) | rating: 2.6
# 75063 | ATM 7ELEVEN, INC. | location: (32.91, -96.99) | rating: 5
# 75063 | First Convenience Bank | location: (32.92, -96.97) | rating: 1.8
# 75063 | ATM Wal-mart | location: (32.92, -96.97) | rating: 4
# 75063 | Credit Union of Texas | location: (32.89, -96.98) | rating: 3.4
# 75063 | First Convenience Bank | location: (32.91, -96.96) | rating: 2.1
# 75063 | Origin Bank | location: (32.91, -96.96) | rating: 5
# 75063 | Southside Bank | location: (32.89, -96.97) | rating: 2.6
# 75063 | Regions Bank | location: (32.91, -96.95) | rating: 3.2
# 75063 | Bank7 | location: (32.9, -96.96) | rating: 5
# 75063 | Chase Bank | location: (32.89, -96.96) | rating: 3.3
# 75063 | Veritex Bank | location: (32.87, -96.99) | rating: 5
# 75063 | Federal Home Loan Bank | location: (32.92, -97.02) | rating: 5
# 75063 | Chase Bank | location: (32.94, -96.99) | rating: 2.6
# 75063 | Chase Bank | location: (32.91, -96.96) | rating: 3.6
# 75063 | North Dallas Bank & Trust Co | location: (32.91, -96.96) | rating: 3.7
# 75063 | Wells Fargo Lockbox | location: (32.92, -96.98) | rating: 5
# 75063 | Frost Bank | location: (32.91, -97.01) | rating: 1
# 75063 | Citi Dallas | location: (32.9, -96.95) | rating: 5
#
# Total number of banks found for 75063: 24 | rating_sum: 78.7 | avg_rating: 3.28
# ------------------------------------------------------------------------------------------------------
#
# 75038 | Comerica Bank | location: (32.87, -96.99) | rating: 2.3
# 75038 | Comerica Bank | location: (32.89, -96.96) | rating: 4.2
# 75038 | Bank of America Financial Center | location: (32.86, -96.99) | rating: 3.2
# 75038 | Capital One Bank | location: (32.87, -96.95) | rating: 3.5
# 75038 | Bank of America Financial Center | location: (32.88, -96.96) | rating: 2.6
# 75038 | Wells Fargo Bank | location: (32.86, -96.96) | rating: 3.5
# 75038 | Veritex Bank | location: (32.87, -96.99) | rating: 5
# 75038 | First Convenience Bank | location: (32.86, -96.99) | rating: 3.4
# 75038 | Credit Union of Texas | location: (32.89, -96.98) | rating: 3.4
# 75038 | Southside Bank | location: (32.89, -96.97) | rating: 2.6
# 75038 | Chase Bank | location: (32.85, -96.99) | rating: 2
# 75038 | Chase Bank | location: (32.89, -96.96) | rating: 3.3
# 75038 | BB&T | location: (32.84, -96.99) | rating: 4.4
# 75038 | BB&T | location: (32.9, -96.96) | rating: 4.1
# 75038 | ATM 7ELEVEN, INC. | location: (32.91, -96.99) | rating: 5
# 75038 | Bank7 | location: (32.9, -96.96) | rating: 5
# 75038 | First Convenience Bank | location: (32.83, -97.01) | rating: 2.7
# 75038 | BBVA Bank | location: (32.87, -96.95) | rating: 3.7
# 75038 | Chase Bank | location: (32.85, -96.99) | rating: 1.4
# 75038 | ATM 7ELEVEN, INC. | location: (32.86, -97.01) | rating: 5
# 75038 | Frost Bank | location: (32.91, -97.01) | rating: 1
#
# Total number of banks found for 75038: 17 | rating_sum: 52.8 | avg_rating: 3.11
# ------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-942feb7167c3> in <module>
#      49
#      50             #call places function
# ---> 51             findPlaces(params)
#      52
#      53             #Loop through results list to count each business and get rating for each
#
# <ipython-input-11-b36c0fd1f27a> in findPlaces(params)
#      15     next_page_token = search_results.get("next_page_token", None)
#      16
# ---> 17     time.sleep(4) #add delay because it can take a moment before the the page token is actually available to make the subsequent call
#      18
#      19     return next_page_token, results_list
#
# KeyboardInterrupt:

# %%
#create file to reference in visualizations (2_visualize-property-values-and-businesses.ipynb) so we don't have to make api calls during presentation
zip_group_df.to_csv('Resources/_zip_group_csv_beta.csv')

# %%
zip_group_df.head()
